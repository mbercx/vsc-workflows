# %%
from vsc_workflows.tools.optics import DielTensor, SolarCell

# %%
diel = DielTensor.from_file('data/CuGaS2_nedos2000.xml')
solar = SolarCell(diel, [1.77, 1.94])

# %%
solar.slme()
# Out:
# /Users/mbercx/project/slme/git/vsc-workflows/vsc_workflows/tools/optics.py:707: UserWarning: Found non-zero absorption below the direct band gap. This may be an indication that the imaginary part of the dielectric function was smeared by the VASP calculation.
#   warnings.warn("Found non-zero absorption below the direct band gap. "
# (0.16875785526946224,
#  1.3849999999999583,
#  134.15150407905782,
#  5.280559971231248e-22)

# %%
solar.plot_slme_vs_thickness()
# Out:
# /Users/mbercx/project/slme/git/vsc-workflows/vsc_workflows/tools/optics.py:707: UserWarning: Found non-zero absorption below the direct band gap. This may be an indication that the imaginary part of the dielectric function was smeared by the VASP calculation.
#   warnings.warn("Found non-zero absorption below the direct band gap. "
